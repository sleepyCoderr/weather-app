# %%
import credentials
import oauth2 as oauth
import urllib3
import json
import pytemperature
import googlemaps
import pprint
from datetime import datetime

# %%
def convertms2mph(num):
    perHour=num*(3600/1)
    perHour=num*(3600/1)
    return perHour/1609

# %%
address ="07726"
gmaps = googlemaps.Client(key='AIzaSyDJnHmIXjElSUi093cL4RocGRddfKYuxIc')
place_result=gmaps.places(query=address,open_now=False)

# zipcode="07726"
city=place_result["results"][0]['formatted_address']
# if zipcode==True:
#     url=f"api.openweathermap.org/data/2.5/weather?zip={zipcode},us&appid=277fd4ecc69a5d9fb08bd31f26881477"

url=f"api.openweathermap.org/data/2.5/forecast?q={city}&appid=277fd4ecc69a5d9fb08bd31f26881477"
city
# Out:
# 'Englishtown, NJ 07726, USA'

# %%
http = urllib3.PoolManager()
r1 = http.request('GET', url1)
r2 = http.request('GET', url2)

results=json.loads(r.data)
results=json.loads(r.data)

results
# Out:
# {'cod': '200',
#  'message': 0.0095,
#  'cnt': 40,
#  'list': [{'dt': 1552068000,
#    'main': {'temp': 277.49,
#     'temp_min': 277.416,
#     'temp_max': 277.49,
#     'pressure': 1028.12,
#     'sea_level': 1028.12,
#     'grnd_level': 1024.37,
#     'humidity': 53,
#     'temp_kf': 0.08},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 1.87, 'deg': 228},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-08 18:00:00'},
#   {'dt': 1552078800,
#    'main': {'temp': 277.63,
#     'temp_min': 277.574,
#     'temp_max': 277.63,
#     'pressure': 1025.58,
#     'sea_level': 1025.58,
#     'grnd_level': 1021.88,
#     'humidity': 55,
#     'temp_kf': 0.06},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 3.06, 'deg': 212.002},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-08 21:00:00'},
#   {'dt': 1552089600,
#    'main': {'temp': 274.79,
#     'temp_min': 274.751,
#     'temp_max': 274.79,
#     'pressure': 1025.34,
#     'sea_level': 1025.34,
#     'grnd_level': 1021.65,
#     'humidity': 76,
#     'temp_kf': 0.04},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 2.62, 'deg': 206},
#    'rain': {'3h': 0.07},
#    'snow': {'3h': 0.00625},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-09 00:00:00'},
#   {'dt': 1552100400,
#    'main': {'temp': 272.21,
#     'temp_min': 272.192,
#     'temp_max': 272.21,
#     'pressure': 1024.53,
#     'sea_level': 1024.53,
#     'grnd_level': 1020.88,
#     'humidity': 95,
#     'temp_kf': 0.02},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 1.61, 'deg': 189.001},
#    'rain': {'3h': 0.005},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-09 03:00:00'},
#   {'dt': 1552111200,
#    'main': {'temp': 270.182,
#     'temp_min': 270.182,
#     'temp_max': 270.182,
#     'pressure': 1024.22,
#     'sea_level': 1024.22,
#     'grnd_level': 1020.53,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 1.22, 'deg': 281.502},
#    'rain': {},
#    'snow': {'3h': 0.00375},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-09 06:00:00'},
#   {'dt': 1552122000,
#    'main': {'temp': 267.992,
#     'temp_min': 267.992,
#     'temp_max': 267.992,
#     'pressure': 1024.15,
#     'sea_level': 1024.15,
#     'grnd_level': 1020.4,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.38, 'deg': 344},
#    'rain': {},
#    'snow': {'3h': 0.0025},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-09 09:00:00'},
#   {'dt': 1552132800,
#    'main': {'temp': 267.1,
#     'temp_min': 267.1,
#     'temp_max': 267.1,
#     'pressure': 1026.02,
#     'sea_level': 1026.02,
#     'grnd_level': 1022.33,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.41, 'deg': 344.002},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-09 12:00:00'},
#   {'dt': 1552143600,
#    'main': {'temp': 277.337,
#     'temp_min': 277.337,
#     'temp_max': 277.337,
#     'pressure': 1027.29,
#     'sea_level': 1027.29,
#     'grnd_level': 1023.68,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.01, 'deg': 22.5032},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-09 15:00:00'},
#   {'dt': 1552154400,
#    'main': {'temp': 280.342,
#     'temp_min': 280.342,
#     'temp_max': 280.342,
#     'pressure': 1026.72,
#     'sea_level': 1026.72,
#     'grnd_level': 1022.91,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.36, 'deg': 69.5019},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-09 18:00:00'},
#   {'dt': 1552165200,
#    'main': {'temp': 280.154,
#     'temp_min': 280.154,
#     'temp_max': 280.154,
#     'pressure': 1026.25,
#     'sea_level': 1026.25,
#     'grnd_level': 1022.54,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.76, 'deg': 96.5003},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-09 21:00:00'},
#   {'dt': 1552176000,
#    'main': {'temp': 274.826,
#     'temp_min': 274.826,
#     'temp_max': 274.826,
#     'pressure': 1027.49,
#     'sea_level': 1027.49,
#     'grnd_level': 1023.9,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '02n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 3.46, 'deg': 105.504},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-10 00:00:00'},
#   {'dt': 1552186800,
#    'main': {'temp': 272.46,
#     'temp_min': 272.46,
#     'temp_max': 272.46,
#     'pressure': 1027.14,
#     'sea_level': 1027.14,
#     'grnd_level': 1023.47,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 3.75, 'deg': 101.002},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-10 03:00:00'},
#   {'dt': 1552197600,
#    'main': {'temp': 274.531,
#     'temp_min': 274.531,
#     'temp_max': 274.531,
#     'pressure': 1025.54,
#     'sea_level': 1025.54,
#     'grnd_level': 1022.08,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 5.04, 'deg': 106.003},
#    'rain': {'3h': 0.125},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-10 06:00:00'},
#   {'dt': 1552208400,
#    'main': {'temp': 276.504,
#     'temp_min': 276.504,
#     'temp_max': 276.504,
#     'pressure': 1021.52,
#     'sea_level': 1021.52,
#     'grnd_level': 1017.92,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 7.53, 'deg': 99.5097},
#    'rain': {'3h': 5.91},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-10 09:00:00'},
#   {'dt': 1552219200,
#    'main': {'temp': 279.14,
#     'temp_min': 279.14,
#     'temp_max': 279.14,
#     'pressure': 1018.16,
#     'sea_level': 1018.16,
#     'grnd_level': 1014.64,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 6.96, 'deg': 110.001},
#    'rain': {'3h': 10.735},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-10 12:00:00'},
#   {'dt': 1552230000,
#    'main': {'temp': 283.082,
#     'temp_min': 283.082,
#     'temp_max': 283.082,
#     'pressure': 1015.57,
#     'sea_level': 1015.57,
#     'grnd_level': 1011.72,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 3.21, 'deg': 199.5},
#    'rain': {'3h': 11.835},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-10 15:00:00'},
#   {'dt': 1552240800,
#    'main': {'temp': 284.096,
#     'temp_min': 284.096,
#     'temp_max': 284.096,
#     'pressure': 1013.65,
#     'sea_level': 1013.65,
#     'grnd_level': 1010.09,
#     'humidity': 100,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 1.52, 'deg': 311.504},
#    'rain': {'3h': 1.355},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-10 18:00:00'},
#   {'dt': 1552251600,
#    'main': {'temp': 285.358,
#     'temp_min': 285.358,
#     'temp_max': 285.358,
#     'pressure': 1012.36,
#     'sea_level': 1012.36,
#     'grnd_level': 1008.8,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 1.27, 'deg': 233.006},
#    'rain': {'3h': 0.125},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-10 21:00:00'},
#   {'dt': 1552262400,
#    'main': {'temp': 282.283,
#     'temp_min': 282.283,
#     'temp_max': 282.283,
#     'pressure': 1012.59,
#     'sea_level': 1012.59,
#     'grnd_level': 1009.05,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 0.67, 'deg': 118},
#    'rain': {'3h': 0.085000000000001},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-11 00:00:00'},
#   {'dt': 1552273200,
#    'main': {'temp': 280.051,
#     'temp_min': 280.051,
#     'temp_max': 280.051,
#     'pressure': 1013.25,
#     'sea_level': 1013.25,
#     'grnd_level': 1009.64,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 0.32, 'deg': 273.001},
#    'rain': {'3h': 0.525},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-11 03:00:00'},
#   {'dt': 1552284000,
#    'main': {'temp': 279.743,
#     'temp_min': 279.743,
#     'temp_max': 279.743,
#     'pressure': 1014.11,
#     'sea_level': 1014.11,
#     'grnd_level': 1010.56,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 4.11, 'deg': 289.003},
#    'rain': {'3h': 0.004999999999999},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-11 06:00:00'},
#   {'dt': 1552294800,
#    'main': {'temp': 278.115,
#     'temp_min': 278.115,
#     'temp_max': 278.115,
#     'pressure': 1015.48,
#     'sea_level': 1015.48,
#     'grnd_level': 1011.87,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 4.82, 'deg': 290.002},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-11 09:00:00'},
#   {'dt': 1552305600,
#    'main': {'temp': 276.122,
#     'temp_min': 276.122,
#     'temp_max': 276.122,
#     'pressure': 1017.63,
#     'sea_level': 1017.63,
#     'grnd_level': 1014.06,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.47, 'deg': 287.002},
#    'rain': {'3h': 0.0050000000000026},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-11 12:00:00'},
#   {'dt': 1552316400,
#    'main': {'temp': 280.625,
#     'temp_min': 280.625,
#     'temp_max': 280.625,
#     'pressure': 1018.93,
#     'sea_level': 1018.93,
#     'grnd_level': 1015.36,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.35, 'deg': 283.501},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-11 15:00:00'},
#   {'dt': 1552327200,
#    'main': {'temp': 282.33,
#     'temp_min': 282.33,
#     'temp_max': 282.33,
#     'pressure': 1017.85,
#     'sea_level': 1017.85,
#     'grnd_level': 1014.24,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.13, 'deg': 281.005},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-11 18:00:00'},
#   {'dt': 1552338000,
#    'main': {'temp': 282.265,
#     'temp_min': 282.265,
#     'temp_max': 282.265,
#     'pressure': 1016.9,
#     'sea_level': 1016.9,
#     'grnd_level': 1013.37,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.71, 'deg': 280.002},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-11 21:00:00'},
#   {'dt': 1552348800,
#    'main': {'temp': 278.398,
#     'temp_min': 278.398,
#     'temp_max': 278.398,
#     'pressure': 1017.98,
#     'sea_level': 1017.98,
#     'grnd_level': 1014.37,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.55, 'deg': 278.001},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-12 00:00:00'},
#   {'dt': 1552359600,
#    'main': {'temp': 276.07,
#     'temp_min': 276.07,
#     'temp_max': 276.07,
#     'pressure': 1019.13,
#     'sea_level': 1019.13,
#     'grnd_level': 1015.57,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.67, 'deg': 281},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-12 03:00:00'},
#   {'dt': 1552370400,
#    'main': {'temp': 274.09,
#     'temp_min': 274.09,
#     'temp_max': 274.09,
#     'pressure': 1020.56,
#     'sea_level': 1020.56,
#     'grnd_level': 1016.92,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.36, 'deg': 299},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-12 06:00:00'},
#   {'dt': 1552381200,
#    'main': {'temp': 271.892,
#     'temp_min': 271.892,
#     'temp_max': 271.892,
#     'pressure': 1021.6,
#     'sea_level': 1021.6,
#     'grnd_level': 1017.95,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.76, 'deg': 296.004},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-12 09:00:00'},
#   {'dt': 1552392000,
#    'main': {'temp': 271.332,
#     'temp_min': 271.332,
#     'temp_max': 271.332,
#     'pressure': 1023.74,
#     'sea_level': 1023.74,
#     'grnd_level': 1020.18,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.66, 'deg': 312.501},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-12 12:00:00'},
#   {'dt': 1552402800,
#    'main': {'temp': 275.892,
#     'temp_min': 275.892,
#     'temp_max': 275.892,
#     'pressure': 1024.25,
#     'sea_level': 1024.25,
#     'grnd_level': 1020.58,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.57, 'deg': 316.502},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-12 15:00:00'},
#   {'dt': 1552413600,
#    'main': {'temp': 279.013,
#     'temp_min': 279.013,
#     'temp_max': 279.013,
#     'pressure': 1023.61,
#     'sea_level': 1023.61,
#     'grnd_level': 1019.95,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.5, 'deg': 312.503},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-12 18:00:00'},
#   {'dt': 1552424400,
#    'main': {'temp': 280.096,
#     'temp_min': 280.096,
#     'temp_max': 280.096,
#     'pressure': 1022.71,
#     'sea_level': 1022.71,
#     'grnd_level': 1019.09,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.87, 'deg': 318.002},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-12 21:00:00'},
#   {'dt': 1552435200,
#    'main': {'temp': 276.698,
#     'temp_min': 276.698,
#     'temp_max': 276.698,
#     'pressure': 1025.72,
#     'sea_level': 1025.72,
#     'grnd_level': 1022.13,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.46, 'deg': 326.503},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-13 00:00:00'},
#   {'dt': 1552446000,
#    'main': {'temp': 274.102,
#     'temp_min': 274.102,
#     'temp_max': 274.102,
#     'pressure': 1028.27,
#     'sea_level': 1028.27,
#     'grnd_level': 1024.55,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.09, 'deg': 348.5},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-13 03:00:00'},
#   {'dt': 1552456800,
#    'main': {'temp': 271.595,
#     'temp_min': 271.595,
#     'temp_max': 271.595,
#     'pressure': 1029.06,
#     'sea_level': 1029.06,
#     'grnd_level': 1025.41,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.26, 'deg': 5.50363},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-13 06:00:00'},
#   {'dt': 1552467600,
#    'main': {'temp': 269.046,
#     'temp_min': 269.046,
#     'temp_max': 269.046,
#     'pressure': 1029.72,
#     'sea_level': 1029.72,
#     'grnd_level': 1026.05,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.2, 'deg': 345.501},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-03-13 09:00:00'},
#   {'dt': 1552478400,
#    'main': {'temp': 268.534,
#     'temp_min': 268.534,
#     'temp_max': 268.534,
#     'pressure': 1030.97,
#     'sea_level': 1030.97,
#     'grnd_level': 1027.22,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.42, 'deg': 329.5},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-13 12:00:00'},
#   {'dt': 1552489200,
#    'main': {'temp': 276.273,
#     'temp_min': 276.273,
#     'temp_max': 276.273,
#     'pressure': 1030.82,
#     'sea_level': 1030.82,
#     'grnd_level': 1027.15,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '02d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.85, 'deg': 33.0025},
#    'rain': {},
#    'snow': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-03-13 15:00:00'}],
#  'city': {'id': 5097686,
#   'name': 'Englishtown',
#   'coord': {'lat': 40.2973, 'lon': -74.3583},
#   'country': 'US',
#   'population': 1847}}

# %%
# main=results['list'][0]
main=results["main"]
main["humidity"]
# Out:
# 53

# %%
#current temp
temp=results["main"]
fahrenheit=pytemperature.k2f(temp["temp"])
night_temp=pytemperature.k2f(temp["temp_min"])


#current speed
speed=results["wind"]["speed"]
mph=round(convertms2mph(speed))

#current humidity
humidity=main["humidity"]

#current cloud
cover=results["weather"][0]["description"]

#current id
ids=results["weather"][0]["id"]

# %%
dict_main={"temp":fahrenheit,"wind":mph,"humidity":humidity,"description":cover,"id":ids,"min_temp":night_temp}
dict_main
# Out:
# {'temp': 28.96,
#  'wind': 8,
#  'humidity': 53,
#  'description': 'clear sky',
#  'id': 800,
#  'min_temp': 24.98}

# %%
dict_main.update({"location":place_result["results"][0]['formatted_address']})

# %%
dict_main
# Out:
# {'temp': 20.26,
#  'wind': 9,
#  'humidity': 53,
#  'description': 'clear sky',
#  'location': 'Englishtown, NJ 07726, USA'}
